# %% [markdown]
# # Welcome to the start of your adventure in Agentic AI

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Are you ready for action??</h2>
#             <span style="color:#ff7800;">Have you completed all the setup steps in the <a href="../setup/">setup</a> folder?<br/>
#             Have you read the <a href="../README.md">README</a>? Many common questions are answered here!<br/>
#             Have you checked out the guides in the <a href="../guides/01_intro.ipynb">guides</a> folder?<br/>
#             Well in that case, you're ready!!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">This code is a live resource - keep an eye out for my updates</h2>
#             <span style="color:#00bfff;">I push updates regularly. As people ask questions or have problems, I add more examples and improve explanations. As a result, the code below might not be identical to the videos, as I've added more steps and better comments. Consider this like an interactive book that accompanies the lectures.<br/><br/>
#             I try to send emails regularly with important updates related to the course. You can find this in the 'Announcements' section of Udemy in the left sidebar. You can also choose to receive my emails via your Notification Settings in Udemy. I'm respectful of your inbox and always try to add value with my emails!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### And please do remember to contact me if I can help
#
# And I love to connect: https://www.linkedin.com/in/eddonner/
#
#
# ### New to Notebooks like this one? Head over to the guides folder!
#
# Just to check you've already added the Python and Jupyter extensions to Cursor, if not already installed:
# - Open extensions (View >> extensions)
# - Search for python, and when the results show, click on the ms-python one, and Install it if not already installed
# - Search for jupyter, and when the results show, click on the Microsoft one, and Install it if not already installed
# Then View >> Explorer to bring back the File Explorer.
#
# And then:
# 1. Click where it says "Select Kernel" near the top right, and select the option called `.venv (Python 3.12.12)` or similar, which should be the first choice or the most prominent choice. You may need to choose "Python Environments" first.
# 2. Click in each "cell" below, starting with the cell immediately below this text, and press Shift+Enter to run
# 3. Enjoy!
#
# After you click "Select Kernel", if there is no option like `.venv (Python 3.12.12)` then please do the following:
# 1. On Mac: From the Cursor menu, choose Settings >> VS Code Settings (NOTE: be sure to select `VSCode Settings` not `Cursor Settings`);
# On Windows PC: From the File menu, choose Preferences >> VS Code Settings(NOTE: be sure to select `VSCode Settings` not `Cursor Settings`)
# 2. In the Settings search bar, type "venv"
# 3. In the field "Path to folder with a list of Virtual Environments" put the path to the project root, like C:\Users\username\projects\agents (on a Windows PC) or /Users/username/projects/agents (on Mac or Linux).
# And then try again.

# %%
# First let's do an import. If you get an Import Error, see Q5 and then Q25 here: https://edwarddonner.com/avatar

from dotenv import load_dotenv

# %%
# Next it's time to load the API keys into environment variables
# If this returns false, see the next cell!

load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ### Wait, did that just output `False`??
#
# If so, the most common reason is that you didn't save your `.env` file after adding the key! Be sure to have saved.
#
# Also, make sure the `.env` file is named precisely `.env` and is in the project root directory (`agents`)
#
# By the way, your `.env` file might have a stop symbol next to it in Cursor on the left, and that's actually a good thing: that's Cursor saying to you, "hey, I realize this is a file filled with secret information, and I'm not going to send it to an external AI to suggest changes, because your keys should not be shown to anyone else."

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Final reminders</h2>
#             <span style="color:#ff7800;">1. If you're not confident about Environment Variables or Web Endpoints / APIs, please read Topics 3 and 5 in this <a href="../guides/04_technical_foundations.ipynb">technical foundations guide</a>.<br/>
#             2. If you want to use AIs other than OpenAI, like Gemini, DeepSeek or Ollama (free), please see the first section in this <a href="../guides/09_ai_apis_and_ollama.ipynb">AI APIs guide</a>.<br/>
#             3. If you ever get a Name Error in Python, you can always fix it immediately; see the last section of this <a href="../guides/06_python_foundations.ipynb">Python Foundations guide</a> and follow both tutorials and exercises.<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Check the key - if you're not using OpenAI, check whichever key you're using! Ollama doesn't need a key.

import os
google_api_key = os.getenv('GOOGLE_API_KEY')

if google_api_key:
    print(f"GoogleAI API Key exists and begins {google_api_key[:8]}")
else:
    print("GoogleAI API Key not set - please head to the troubleshooting guide in the setup folder")
# Out:
# GoogleAI API Key exists and begins AQ.Ab8RN

# %%
# And now - the all important import statement
# If you get an import error - head over to Q5 and Q25 in the FAQ at https://edwarddonner.com/avatar
# Even for other LLM providers like Gemini, you still use this OpenAI import - see Guide 9 for why

from openai import OpenAI

# %%
# And now we'll create an instance of the OpenAI class
# If you're not sure what it means to create an instance of a class - head over to the guides folder (guide 6)!
# If you get a NameError - head over to the guides folder (guide 6)to learn about NameErrors - always instantly fixable
# If you're not using OpenAI, you just need to slightly modify this - precise instructions are in the AI APIs guide (guide 9)
GEMINI_BASE_URL = "https://generativelanguage.googleapis.com/v1beta/openai/"

gemini = OpenAI(base_url=GEMINI_BASE_URL, api_key= google_api_key)

# %%
# Create a list of messages in the familiar OpenAI format

messages = [{"role": "user", "content": "what is 5+5?"}]

# %%
messages
# Out:
# [{'role': 'user', 'content': 'what is 5+5?'}]

# %%
# And now call it! Any problems, head to the troubleshooting guide
# This uses GPT 5.4 nano, an incredibly cheap model
# The APIs guide (guide 9) has exact instructions for using even cheaper or free alternatives to OpenAI
# If you get a NameError, head to the guides folder (guide 6) to learn about NameErrors - always instantly fixable


response = gemini.chat.completions.create(model = "gemini-2.5-flash-lite", messages= messages)

print(response.choices[0].message.content)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[40], line 7
#       3 # The APIs guide (guide 9) has exact instructions for using even cheaper or free alternatives to OpenAI
#       4 # If you get a NameError, head to the guides folder (guide 6) to learn about NameErrors - always instantly fixable
#       5
#       6
# ----> 7 response = gemini.chat.completions.create(model = "gemini-2.5-flash-lite", messages= messages)
#       8
#       9 print(response.choices[0].message.content)
#
# File c:\Users\Abokh\Desktop\projects\agents\.venv\Lib\site-packages\openai\_utils\_utils.py:298, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     296             msg = f"Missing required argument: {quote(missing[0])}"
#     297     raise TypeError(msg)
# --> 298 return func(*args, **kwargs)
#
# File c:\Users\Abokh\Desktop\projects\agents\.venv\Lib\site-packages\openai\resources\chat\completions\completions.py:1212, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1165 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1166 def create(
#    1167     self,
#    (...)   1209     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1210 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1211     validate_response_format(response_format)
# -> 1212     return self._post(
#    1213         "/chat/completions",
#    1214         body=maybe_transform(
#    1215             {
#    1216                 "messages": messages,
#    1217                 "model": model,
#    1218                 "audio": audio,
#    1219                 "frequency_penalty": frequency_penalty,
#    1220                 "function_call": function_call,
#    1221                 "functions": functions,
#    1222                 "logit_bias": logit_bias,
#    1223                 "logprobs": logprobs,
#    1224                 "max_completion_tokens": max_completion_tokens,
#    1225                 "max_tokens": max_tokens,
#    1226                 "metadata": metadata,
#    1227                 "modalities": modalities,
#    1228                 "n": n,
#    1229                 "parallel_tool_calls": parallel_tool_calls,
#    1230                 "prediction": prediction,
#    1231                 "presence_penalty": presence_penalty,
#    1232                 "prompt_cache_key": prompt_cache_key,
#    1233                 "prompt_cache_retention": prompt_cache_retention,
#    1234                 "reasoning_effort": reasoning_effort,
#    1235                 "response_format": response_format,
#    1236                 "safety_identifier": safety_identifier,
#    1237                 "seed": seed,
#    1238                 "service_tier": service_tier,
#    1239                 "stop": stop,
#    1240                 "store": store,
#    1241                 "stream": stream,
#    1242                 "stream_options": stream_options,
#    1243                 "temperature": temperature,
#    1244                 "tool_choice": tool_choice,
#    1245                 "tools": tools,
#    1246                 "top_logprobs": top_logprobs,
#    1247                 "top_p": top_p,
#    1248                 "user": user,
#    1249                 "verbosity": verbosity,
#    1250                 "web_search_options": web_search_options,
#    1251             },
#    1252             completion_create_params.CompletionCreateParamsStreaming
#    1253             if stream
#    1254             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1255         ),
#    1256         options=make_request_options(
#    1257             extra_headers=extra_headers,
#    1258             extra_query=extra_query,
#    1259             extra_body=extra_body,
#    1260             timeout=timeout,
#    1261             security={"bearer_auth": True},
#    1262         ),
#    1263         cast_to=ChatCompletion,
#    1264         stream=stream or False,
#    1265         stream_cls=Stream[ChatCompletionChunk],
#    1266     )
#
# File c:\Users\Abokh\Desktop\projects\agents\.venv\Lib\site-packages\openai\_base_client.py:1332, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1323     warnings.warn(
#    1324         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1325         "Please pass raw bytes via the `content` parameter instead.",
#    1326         DeprecationWarning,
#    1327         stacklevel=2,
#    1328     )
#    1329 opts = FinalRequestOptions.construct(
#    1330     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1331 )
# -> 1332 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\Abokh\Desktop\projects\agents\.venv\Lib\site-packages\openai\_base_client.py:1105, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1102             err.response.read()
#    1104         log.debug("Re-raising status error")
# -> 1105         raise self._make_status_error_from_response(err.response) from None
#    1107     break
#    1109 assert response is not None, "could not resolve response (should never happen)"
#
# RateLimitError: Error code: 429 - [{'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash-lite\nPlease retry in 24.828864225s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'model': 'gemini-2.5-flash-lite', 'location': 'global'}, 'quotaValue': '20'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '24s'}]}}]

# %%
# And now - let's ask for a question:

question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
messages = [{"role":"user", "content": question}]

# %%
messages
# Out:
# [{'role': 'user',
#   'content': "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."}]

# %%
# ask it - this uses GPT 5.4 mini, still cheap but more powerful than nano

response = gemini.chat.completions.create(model = "gemini-2.5-flash-lite", messages= messages)
question = response.choices[0].message.content
print(question)
# Out:
# If you have a clock that only shows hours and minutes, and all numbers are replaced by letters, with each letter representing a unique digit from 0 to 9, and the time displayed is "II:VI", what is the *earliest possible* valid time it could be?

# %%
# form a new messages list

messages = [{"role": "user", "content": question}]
messages
# Out:
# [{'role': 'user',
#   'content': 'If you have a clock that only shows hours and minutes, and all numbers are replaced by letters, with each letter representing a unique digit from 0 to 9, and the time displayed is "II:VI", what is the *earliest possible* valid time it could be?'}]

# %%
# Ask the model to answer the hard question

response = gemini.chat.completions.create(model="gemini-2.5-flash-lite", messages=messages)
answer = response.choices[0].message.content
print(answer)
# Out:
# Here's how to solve this puzzle:
#
# **Understanding the Constraints**
#
# * **Unique Digits:** Each letter (I, V) represents a unique digit from 0 to 9.
# * **Clock Format:** The time is in HH:MM format.
# * **Displayed Time:** II:VI
#
# **Deducing the Digits**
#
# 1. **The "I" Digit:** In the hours position (II), the letter "I" represents the same digit. This means the hour must be a two-digit number where both digits are the same. The possible hours are 00, 11, 22, 33, 44, 55, 66, 77, 88, 99.
#    However, a clock only goes up to 23 for hours. So, the only possibility for "II" representing a valid hour is **11**.
#    Therefore, **I = 1**.
#
# 2. **The "V" Digit:** Now we know I = 1. The time displayed is II:VI, which translates to 11:V1.
#    The minutes section is "VI". We know I = 1. So, this becomes V1.
#    The possible digits for "V" must be a digit from 0 to 9 that is *not* 1 (because all digits must be unique).
#
# 3. **Finding the Earliest Possible Time:** We are looking for the *earliest possible* valid time. This means we want the smallest possible valid hour and then the smallest possible valid minute.
#
#     * **Hour:** We've already determined the hour must be 11.
#
#     * **Minutes:** The minutes are represented by "VI", which translates to "V1". Since "I" is 1, the minutes are "V1". The possible digits for "V" are 0, 2, 3, 4, 5, 6, 7, 8, 9.
#
#     To get the earliest possible time, we need the smallest possible digit for "V". The smallest available digit is **0**.
#
#     Therefore, **V = 0**.
#
# **Constructing the Time**
#
# * **Hour:** II = 11
# * **Minutes:** VI = 01
#
# **The Earliest Possible Time**
#
# The earliest possible valid time it could be is **11:01**.

# %%
from IPython.display import Markdown, display

display(Markdown(answer))
# Out:
# Here's how to solve this puzzle:
#
# **Understanding the Constraints**
#
# * **Unique Digits:** Each letter (I, V) represents a unique digit from 0 to 9.
# * **Clock Format:** The time is in HH:MM format.
# * **Displayed Time:** II:VI
#
# **Deducing the Digits**
#
# 1. **The "I" Digit:** In the hours position (II), the letter "I" represents the same digit. This means the hour must be a two-digit number where both digits are the same. The possible hours are 00, 11, 22, 33, 44, 55, 66, 77, 88, 99.
#    However, a clock only goes up to 23 for hours. So, the only possibility for "II" representing a valid hour is **11**.
#    Therefore, **I = 1**.
#
# 2. **The "V" Digit:** Now we know I = 1. The time displayed is II:VI, which translates to 11:V1.
#    The minutes section is "VI". We know I = 1. So, this becomes V1.
#    The possible digits for "V" must be a digit from 0 to 9 that is *not* 1 (because all digits must be unique).
#
# 3. **Finding the Earliest Possible Time:** We are looking for the *earliest possible* valid time. This means we want the smallest possible valid hour and then the smallest possible valid minute.
#
#     * **Hour:** We've already determined the hour must be 11.
#
#     * **Minutes:** The minutes are represented by "VI", which translates to "V1". Since "I" is 1, the minutes are "V1". The possible digits for "V" are 0, 2, 3, 4, 5, 6, 7, 8, 9.
#
#     To get the earliest possible time, we need the smallest possible digit for "V". The smallest available digit is **0**.
#
#     Therefore, **V = 0**.
#
# **Constructing the Time**
#
# * **Hour:** II = 11
# * **Minutes:** VI = 01
#
# **The Earliest Possible Time**
#
# The earliest possible valid time it could be is **11:01**.

# %%
message = f"""
Here is a question:
{question}

And here is a possible answer that might be correct or incorrect:
{answer}

Please evaluate if the answer is correct or incorrect.
"""

print(message)

# %%
messages = [{"role": "user", "content": message}]
response = openai.chat.completions.create(model="gpt-5.4", messages=messages)
print(response.choices[0].message.content)

# %% [markdown]
# # Congratulations!
#
# That was a small, simple step in the direction of Agentic AI, with your new environment!
#
# Next time things get more interesting...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Now try this commercial application:<br/>
#             First ask the LLM to pick a business area that might be worth exploring for an Agentic AI opportunity.<br/>
#             Then ask the LLM to present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.<br/>
#             Finally have 3 third LLM call propose the Agentic AI solution. <br/>
#             We will cover this at up-coming labs, so don't worry if you're unsure.. just give it a try!
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# First create the messages:

messages = [{"role": "user", "content": "You have to think for business area that might be worth exploring for an Agentic AI opportunity"}]

# Then make the first call:

response = gemini.chat.completions.create(model= "gemini-2.5-flash-lite", messages= messages)

# Then read the business idea:

business_area = response.choices[0].message.content

# And repeat! In the next message, include the business area within the message

messages = [{"role": "user", "content": f"You have to present a pain-point in this industry {business_area} which might be a ripe for an Agentic solution"}]

response = gemini.chat.completions.create(model= "gemini-2.5-flash-lite", messages= messages)

Pain_Point = response.choices[0].message.content


messages = [{"role":"user", "content":f"""Here is a pain-point that we fouind:
{Pain_Point},

Your role is to propose the Agenti AI solution"""}]
response = gemini.chat.completions.create(model= "gemini-2.5-flash-lite", messages= messages)
answer = response.choices[0].message.content

print(answer)
# Out:
# This is an excellent and thorough framing of the pain point! It clearly articulates the risks associated with autonomous decision-making in Agentic AI, which is crucial for understanding the need for effective solutions.
#
# Now, let's pivot to proposing the Agentic AI solution itself, and how it can *address* this very pain point.
#
# ---
#
# ## The Agentic AI Solution: **Guardian Agents - The Pillars of Predictable Autonomy**
#
# The pain point of "The Double-Edged Sword of Autonomy" highlights a critical need: not just for autonomous AI, but for *responsible, predictable, and controllable* autonomous AI. Our Agentic AI solution, which we'll call **Guardian Agents**, is specifically designed to tackle this head-on. Guardian Agents are not just about making decisions; they are built with inherent safeguards, transparent reasoning capabilities, and robust oversight mechanisms that turn the potential risks into manageable, even advantageous, components of their operation.
#
# **How Guardian Agents Address the Pain Point:**
#
# Instead of viewing autonomy as a free-for-all, Guardian Agents implement a layered approach to control and predictability, ensuring that the power of autonomous decision-making is harnessed safely and effectively.
#
# **1. Proactive Risk Assessment & Predictive Mitigation Frameworks:**
#
# *   **How it Addresses the Pain Point:** Directly counters the "misinterpretation" and "unforeseen emergent behaviors" concerns.
# *   **Our Solution:** Guardian Agents are equipped with sophisticated **risk assessment modules** that continuously analyze potential scenarios and their likely impact *before* an action is taken. This includes:
#     *   **Probabilistic Consequence Modeling:** Before executing a significant decision, the agent models the probable outcomes and their associated confidence levels. If the probability of negative consequences exceeds a predefined threshold, the action is flagged or escalated.
#     *   **"What-If" Simulation Engines:** Guardian Agents can run real-time simulations of their proposed actions within a virtual sandbox environment, allowing them to test hypotheses and refine decisions without impacting live systems.
#     *   **Dynamic Constraint Monitoring:** Agents operate within explicitly defined, dynamic operational boundaries that are continuously monitored and adjusted based on real-time context and risk assessments.
#
# **2. Explainable AI (XAI) for Transparent Decision-Making:**
#
# *   **How it Addresses the Pain Point:** Directly tackles the "Black Box Problem" and builds trust.
# *   **Our Solution:** Guardian Agents are built on a foundation of **explainable AI**. This means:
#     *   **Step-by-Step Reasoning Trails:** Every significant decision made by a Guardian Agent is accompanied by a clear, human-readable explanation of the factors, data, and logic that led to that conclusion. This allows for easy auditing and debugging.
#     *   **Causal Attribution:** When an unexpected outcome occurs, the XAI capabilities allow us to pinpoint the exact causal chain of events and the specific inputs or logic that contributed to it, facilitating rapid correction.
#     *   **Interactive Debugging Interfaces:** For complex scenarios, human operators can interact with the agent to probe its reasoning, ask clarifying questions, and even guide its decision-making process in real-time.
#
# **3. Human-in-the-Loop (HITL) & Escalation Protocols:**
#
# *   **How it Addresses the Pain Point:** Solves the "Human Oversight Paradox" and establishes accountability.
# *   **Our Solution:** Guardian Agents embrace a **flexible HITL model**, not as a limitation, but as a strength:
#     *   **Tiered Autonomy Levels:** Agents can operate at different levels of autonomy, from fully autonomous for routine tasks to requiring explicit human approval for high-stakes or ambiguous situations.
#     *   **Intelligent Escalation:** When an agent encounters a situation outside its predefined confidence parameters or detects a high-risk scenario, it automatically escalates the decision to a human expert, providing them with all relevant context and its own recommended course of action.
#     *   **"Guardrail" Monitoring and Override:** Human supervisors have a clear dashboard for monitoring agent activity and possess the ability to override any autonomous decision that is deemed inappropriate or risky.
#
# **4. Adaptive Learning with Controlled Experimentation:**
#
# *   **How it Addresses the Pain Point:** Manages "Unforeseen Emergent Behaviors" by guiding learning.
# *   **Our Solution:** Guardian Agents learn and adapt, but in a controlled and safety-conscious manner:
#     *   **Reinforcement Learning with Safety Constraints:** Reinforcement learning algorithms are employed, but with stringent safety constraints and reward functions that penalize undesirable or risky behaviors.
#     *   **Federated Learning and Sandboxed Training:** For learning from new data, agents can utilize federated learning approaches to train on distributed datasets without compromising data privacy, or undergo extensive training in secure sandboxed environments before deployment.
#     *   **Continuous Performance Monitoring and Drift Detection:** We continuously monitor agent performance for any signs of drift or unexpected behavioral changes, triggering alerts and retraining protocols when necessary.
#
# **5. Robust Auditing and Accountability Frameworks:**
#
# *   **How it Addresses the Pain Point:** Directly addresses "Trust and Accountability."
# *   **Our Solution:** Guardian Agents are designed with a complete audit trail from inception:
#     *   **Immutable Decision Logs:** All agent actions, decisions, and data inputs are recorded in an immutable log, providing irrefutable evidence of their operational history.
#     *   **Role-Based Access Control:** Clear roles and permissions define who can configure, monitor, and interact with Guardian Agents, ensuring that accountability is clearly assigned.
#     *   **Automated Compliance Checks:** Agents can be programmed to perform automated checks against regulatory requirements and internal policies, ensuring ongoing adherence.
#
# **The "Why" of the Guardian Agent Solution:**
#
# Guardian Agents transform the inherent complexity and risk of Agentic AI from a barrier into a feature of responsible innovation. By prioritizing transparency, control, and proactive risk management, we enable businesses to confidently explore the "vast landscapes of business opportunities" not by ignoring the risks, but by actively mitigating them.
#
# **In essence, our Agentic AI solution, Guardian Agents, provides the critical framework for realizing the promise of autonomous AI by ensuring that decisions are not just intelligent, but also justifiable, predictable, and ultimately, safe. We don't just aim for autonomous action; we aim for *accountable autonomy*.**

# %%
from IPython.display import Markdown, display

messages = [{"role":"user", "content": f"Translate this text to Arabic{answer}."}]
response = gemini.chat.completions.create(model="gemini-2.5-flash-lite",messages= messages)

display(Markdown(response.choices[0].message.content))
# Out:
# هذا تأطير ممتاز وشامل لنقطة الألم! إنه يوضح بوضوح المخاطر المرتبطة باتخاذ القرارات الذاتية في الذكاء الاصطناعي الوكيل (Agentic AI)، وهو أمر بالغ الأهمية لفهم الحاجة إلى حلول فعالة.
#
# الآن، دعنا ننتقل إلى اقتراح حل الذكاء الاصطناعي الوكيل نفسه، وكيف يمكنه *معالجة* نقطة الألم هذه تحديدًا.
#
# ---
#
# ## حل الذكاء الاصطناعي الوكيل: **وكلاء الحراسة - ركائز الاستقلالية القابلة للتنبؤ**
#
# تُسلط نقطة الألم "السيف ذو الحدين للاستقلالية" الضوء على حاجة حرجة: ليس فقط للذكاء الاصطناعي المستقل، بل للذكاء الاصطناعي المستقل *المسؤول، والقابل للتنبؤ، والقابل للتحكم*. تم تصميم حلنا للذكاء الاصطناعي الوكيل، والذي سنطلق عليه اسم **وكلاء الحراسة**، خصيصًا لمعالجة هذا الأمر بشكل مباشر. وكلاء الحراسة لا يتعلقون فقط باتخاذ القرارات؛ بل تم بناؤهم بضمانات متأصلة، وقدرات استدلال شفافة، وآليات رقابة قوية تحوّل المخاطر المحتملة إلى مكونات قابلة للإدارة، بل ومفيدة، لعملياتهم.
#
# **كيف تعالج وكلاء الحراسة نقطة الألم:**
#
# بدلاً من النظر إلى الاستقلالية على أنها فوضى عارمة، تُطبق وكلاء الحراسة نهجًا متعدد الطبقات للتحكم والقابلية للتنبؤ، مما يضمن تسخير قوة اتخاذ القرارات الذاتية بأمان وفعالية.
#
# **1. أطر عمل تقييم المخاطر الاستباقي والتخفيف التنبؤي:**
#
# *   **كيف تعالج نقطة الألم:** تقاوم بشكل مباشر مخاوف "سوء التفسير" و "السلوكيات الناشئة غير المتوقعة".
# *   **حلنا:** تم تجهيز وكلاء الحراسة بـ **وحدات تقييم المخاطر** المتطورة التي تحلل باستمرار السيناريوهات المحتملة وتأثيرها المرجح *قبل* اتخاذ إجراء. يشمل ذلك:
#     *   **نمذجة العواقب الاحتمالية:** قبل تنفيذ قرار مهم، يقوم الوكيل بنمذجة النتائج المحتملة ومستويات الثقة المرتبطة بها. إذا تجاوز احتمال العواقب السلبية عتبة محددة مسبقًا، يتم وضع علامة على الإجراء أو تصعيده.
#     *   **محركات محاكاة "ماذا لو":** يمكن لوكلاء الحراسة تشغيل محاكاة في الوقت الفعلي للإجراءات المقترحة في بيئة اختبار افتراضية (sandbox)، مما يسمح لهم باختبار الفرضيات وصقل القرارات دون التأثير على الأنظمة الحية.
#     *   **مراقبة القيود الديناميكية:** يعمل الوكلاء ضمن حدود تشغيلية محددة بوضوح وديناميكية يتم مراقبتها وتعديلها باستمرار بناءً على السياق في الوقت الفعلي وتقييمات المخاطر.
#
# **2. الذكاء الاصطناعي القابل للتفسير (XAI) لاتخاذ قرارات شفافة:**
#
# *   **كيف تعالج نقطة الألم:** تعالج بشكل مباشر "مشكلة الصندوق الأسود" وتبني الثقة.
# *   **حلنا:** تم بناء وكلاء الحراسة على أساس **الذكاء الاصطناعي القابل للتفسير**. هذا يعني:
#     *   **مسارات الاستدلال خطوة بخطوة:** كل قرار مهم يتخذه وكيل الحراسة يكون مصحوبًا بتفسير واضح وسهل القراءة للعوامل والبيانات والمنطق الذي أدى إلى هذا الاستنتاج. هذا يتيح سهولة التدقيق واستكشاف الأخطاء وإصلاحها.
#     *   **الإسناد السببي:** عند حدوث نتيجة غير متوقعة، تسمح قدرات الذكاء الاصطناعي القابل للتفسير لنا بتحديد سلسلة الأحداث السببية الدقيقة والمدخلات أو المنطق المحدد الذي ساهم فيها، مما يسهل التصحيح السريع.
#     *   **واجهات تصحيح تفاعلية:** للسيناريوهات المعقدة، يمكن للمشغلين البشريين التفاعل مع الوكيل لاستقصاء منطقه، وطرح أسئلة توضيحية، وحتى توجيه عملية اتخاذ القرار في الوقت الفعلي.
#
# **3. بروتوكولات التدخل البشري (HITL) والتصعيد:**
#
# *   **كيف تعالج نقطة الألم:** تحل "مفارقة الإشراف البشري" وتؤسس المساءلة.
# *   **حلنا:** تتبنى وكلاء الحراسة نموذج **التدخل البشري المرن (HITL)**، وليس كقيود، بل كنقطة قوة:
#     *   **مستويات استقلالية متدرجة:** يمكن للوكلاء العمل بمستويات مختلفة من الاستقلالية، من الاستقلالية الكاملة للمهام الروتينية إلى الحاجة إلى موافقة بشرية صريحة في المواقف عالية المخاطر أو الغامضة.
#     *   **التصعيد الذكي:** عندما يواجه الوكيل موقفًا خارج معلمات الثقة المحددة مسبقًا أو يكتشف سيناريو عالي المخاطر، فإنه يصعد القرار تلقائيًا إلى خبير بشري، ويزوده بكل السياق ذي الصلة ومسار العمل الموصى به.
#     *   **مراقبة "الحواجز الواقية" والتجاوز:** يتمتع المشرفون البشريون بلوحة تحكم واضحة لمراقبة نشاط الوكيل ويمتلكون القدرة على تجاوز أي قرار مستقل يعتبر غير مناسب أو محفوف بالمخاطر.
#
# **4. التعلم التكيفي مع التجريب المتحكم فيه:**
#
# *   **كيف تعالج نقطة الألم:** تدير "السلوكيات الناشئة غير المتوقعة" من خلال توجيه التعلم.
# *   **حلنا:** تتعلم وكلاء الحراسة وتتكيف، ولكن بطريقة متحكم فيها وحذرة من ناحية السلامة:
#     *   **التعلم المعزز بقيود السلامة:** يتم استخدام خوارزميات التعلم المعزز، ولكن مع قيود سلامة صارمة ودوال مكافأة تعاقب السلوكيات غير المرغوب فيها أو المحفوفة بالمخاطر.
#     *   **التعلم الموحد والتدريب في بيئات معزولة:** للتعلم من البيانات الجديدة، يمكن للوكلاء استخدام أساليب التعلم الموحد للتدريب على مجموعات بيانات موزعة دون المساس بخصوصية البيانات، أو الخضوع لتدريب مكثف في بيئات معزولة آمنة قبل النشر.
#     *   **مراقبة الأداء المستمرة وكشف الانحراف:** نقوم باستمرار بمراقبة أداء الوكيل بحثًا عن أي علامات للانحراف أو تغييرات سلوكية غير متوقعة، مما يؤدي إلى تشغيل تنبيهات وبروتوكولات إعادة التدريب عند الضرورة.
#
# **5. أطر عمل قوية للتدقيق والمساءلة:**
#
# *   **كيف تعالج نقطة الألم:** تعالج بشكل مباشر "الثقة والمساءلة".
# *   **حلنا:** تم تصميم وكلاء الحراسة مع سجل تدقيق كامل منذ البداية:
#     *   **سجلات قرارات غير قابلة للتغيير:** يتم تسجيل جميع إجراءات الوكيل وقراراته والمدخلات البيانية في سجل غير قابل للتغيير، مما يوفر دليلًا قاطعًا على تاريخ تشغيلها.
#     *   **التحكم في الوصول المستند إلى الأدوار:** تحدد الأدوار والأذونات الواضحة من يمكنه تكوين وكلاء الحراسة أو مراقبتهم أو التفاعل معهم، مما يضمن تعيين المساءلة بوضوح.
#     *   **فحوصات الامتثال الآلية:** يمكن برمجة الوكلاء لإجراء فحوصات آلية مقابل المتطلبات التنظيمية والسياسات الداخلية، مما يضمن الامتثال المستمر.
#
# **"لماذا" حل وكلاء الحراسة:**
#
# تحول وكلاء الحراسة التعقيد والمخاطر المتأصلة في الذكاء الاصطناعي الوكيل من حاجز إلى ميزة للابتكار المسؤول. من خلال إعطاء الأولوية للشفافية والتحكم وإدارة المخاطر الاستباقية، نمكّن الشركات من استكشاف "المناظر الطبيعية الواسعة لفرص الأعمال" بثقة، ليس عن طريق تجاهل المخاطر، بل عن طريق التخفيف منها بنشاط.
#
# **باختصار، يوفر حلنا للذكاء الاصطناعي الوكيل، وكلاء الحراسة، الإطار الحاسم لتحقيق وعد الذكاء الاصطناعي المستقل من خلال ضمان أن القرارات ليست ذكية فحسب، بل أيضًا قابلة للتبرير، وقابلة للتنبؤ، وفي النهاية، آمنة. نحن لا نهدف فقط إلى العمل المستقل؛ بل نهدف إلى "الاستقلالية المسؤولة".**
